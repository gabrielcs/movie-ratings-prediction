# %% [markdown]
# # Regression Open-Ended Project

# %% [markdown]
# -----

# %% [markdown]
# # Previous Notebooks
#
# - Web Scraping
# - Cleaning data
# - Exploratory Data Analysis
# - Feature Engineering
# - Further Explatory Data Analysis

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Modeling (Linear Regression without Genres, Directors, Actors, Decades)

# %% [markdown]
# We'll start by using Statsmodels to build a Linear Regression model without using high-dimenisonal features (directors, actors, and others). We will therefore select the features manually.

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
ebert_imdb_df = pickle.load(open('data/ebert_imdb_df_v6.pkl', 'rb'))

# %%
ebert_imdb_df.columns[:60]
# Out:
# Index(['Title', 'IMDB_Rating', 'Rating_Count', 'Description', 'Metascore',
#        'User_Review_Count', 'Critic_Review_Count', 'Country', 'Release_Date',
#        'EbertStars', 'Year', 'URL', 'Rating', 'Runtime', 'Review', 'Foreign',
#        'UC_Ratio', 'Description_Len', 'Review_Len', 'Season', 'Fall', 'Spring',
#        'Summer', 'Winter', 'G', 'NC-17', 'PG', 'PG-13', 'R', 'Unrated',
#        'Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Documentary', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'Game-Show',
#        'History', 'Horror', 'Music', 'Musical', 'Mystery', 'News',
#        'Reality-TV', 'Romance', 'Sci-Fi', 'Short', 'Sport', 'Talk-Show',
#        'Thriller', 'War', 'Western', '', 'Aaron Blaise', 'Aaron Katz'],
#       dtype='object')

# %%
ebert_imdb_df.columns[-15:]
# Out:
# Index(['Zooey Deschanel',     'Zoë Kravitz',     'Zulay Henao',
#         'Élodie Bouchez', 'Émilie Dequenne',              1920,
#                     1930,              1940,              1950,
#                     1960,              1970,              1980,
#                     1990,              2000,              2010],
#       dtype='object')

# %%
regression_df = ebert_imdb_df[['Title', 'IMDB_Rating', 'Rating_Count', 'Metascore',
       'User_Review_Count', 'Critic_Review_Count', 'Year', 'EbertStars', 'Runtime', 
        'Foreign', 'UC_Ratio', 'Description_Len', 'Review_Len', 'Season']]

# %%
df_season = pd.get_dummies(regression_df['Season'])
regression_df = pd.concat([regression_df, df_season], axis=1)

# %%
regression_df = regression_df.dropna()

# %%
train, test = train_test_split(regression_df, test_size=0.33, random_state=42)

# %%
X = train.drop(['Season', 'Title', 'Year', 'EbertStars'], axis=1)
y = train['EbertStars']

# %% [markdown]
# ### Baseline Model

# %%
ebert_imdb_df.EbertStars.mode()
# Out:
# 0    3.0
# dtype: float64

# %%
y_test = test['EbertStars']
baseline = [3.0] * len(y_test)

# %%
baseline_error = mean_squared_error(y_test, baseline)
print('Baseline Algorithm Error: ', baseline_error)
# Out:
# Baseline Algorithm Error:  0.83736349454

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
print(results.params)
results.summary()
# Out:
# const                 -1.287586e-01
# IMDB_Rating            7.534732e-02
# Rating_Count          -8.375849e-08
# Metascore              2.852019e-02
# User_Review_Count     -1.732272e-04
# Critic_Review_Count    1.204426e-04
# Runtime                2.640074e-03
# Foreign               -1.572688e-02
# UC_Ratio               3.777512e-02
# Description_Len       -5.829899e-04
# Review_Len             5.256826e-04
# Fall                  -3.972394e-02
# Spring                -3.368535e-02
# Summer                -3.298553e-02
# Winter                -2.236381e-02
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             EbertStars   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     238.7
# Date:                Sat, 27 May 2017   Prob (F-statistic):               0.00
# Time:                        22:21:00   Log-Likelihood:                -3778.6
# No. Observations:                3904   AIC:                             7585.
# Df Residuals:                    3890   BIC:                             7673.
# Df Model:                          13
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1288      0.085     -1.510      0.131      -0.296       0.038
# IMDB_Rating             0.0753      0.018      4.284      0.000       0.041       0.110
# Rating_Count        -8.376e-08   1.54e-07     -0.546      0.585   -3.85e-07    2.17e-07
# Metascore               0.0285      0.001     32.095      0.000       0.027       0.030
# User_Review_Count      -0.0002   7.46e-05     -2.322      0.020      -0.000   -2.69e-05
# Critic_Review_Count     0.0001      0.000      0.812      0.417      -0.000       0.000
# Runtime                 0.0026      0.001      4.238      0.000       0.001       0.004
# Foreign                -0.0157      0.029     -0.552      0.581      -0.072       0.040
# UC_Ratio                0.0378      0.013      2.855      0.004       0.012       0.064
# Description_Len        -0.0006      0.001     -0.800      0.424      -0.002       0.001
# Review_Len              0.0005   5.45e-05      9.639      0.000       0.000       0.001
# Fall                   -0.0397      0.028     -1.412      0.158      -0.095       0.015
# Spring                 -0.0337      0.027     -1.235      0.217      -0.087       0.020
# Summer                 -0.0330      0.027     -1.235      0.217      -0.085       0.019
# Winter                 -0.0224      0.029     -0.770      0.441      -0.079       0.035
# ==============================================================================
# Omnibus:                      230.502   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              324.163
# Skew:                          -0.524   Prob(JB):                     4.06e-71
# Kurtosis:                       3.945   Cond. No.                     1.12e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.22e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X = test.drop(['Season', 'Title', 'Year', 'EbertStars'], axis=1)
y = test['EbertStars']

# %%
def half_round(x, prec=1, base=.5):
    return round(base * round(float(x) / base), prec)

# %%
predictions = results.predict(sm.add_constant(X))
y_round = [half_round(y) for y in predictions]
print('Linear Regression Error: ', mean_squared_error(y, y_round))
# Out:
# Linear Regression Error:  0.417446697868

# %% [markdown]
# ## Predict post-Ebert movies (instead of random train / test split)

# %%
post_ebert = regression_df[regression_df['Year'] >= 2013]
pre_ebert = regression_df[regression_df['Year'] < 2013]

# %%
print(post_ebert.shape)
print(pre_ebert.shape)
# Out:
# (1899, 18)
# (3928, 18)

# %%
X = pre_ebert.drop(['Season', 'Title', 'Year', 'EbertStars'], axis=1)
y = pre_ebert['EbertStars']

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X)
results = model.fit()
print(results.params)
results.summary()
# Out:
# const                 -1.307500e-01
# IMDB_Rating            8.916902e-02
# Rating_Count          -1.322353e-07
# Metascore              2.519377e-02
# User_Review_Count     -4.146950e-05
# Critic_Review_Count    9.131121e-05
# Runtime                1.465926e-03
# Foreign               -7.717471e-02
# UC_Ratio              -4.828906e-02
# Description_Len       -6.037064e-04
# Review_Len             1.063082e-03
# Fall                  -2.654290e-02
# Spring                -6.272251e-02
# Summer                -4.101069e-03
# Winter                -3.738353e-02
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             EbertStars   R-squared:                       0.453
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     249.2
# Date:                Sat, 27 May 2017   Prob (F-statistic):               0.00
# Time:                        22:21:00   Log-Likelihood:                -3639.0
# No. Observations:                3928   AIC:                             7306.
# Df Residuals:                    3914   BIC:                             7394.
# Df Model:                          13
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1308      0.084     -1.548      0.122      -0.296       0.035
# IMDB_Rating             0.0892      0.017      5.125      0.000       0.055       0.123
# Rating_Count        -1.322e-07   1.29e-07     -1.027      0.304   -3.85e-07     1.2e-07
# Metascore               0.0252      0.001     28.564      0.000       0.023       0.027
# User_Review_Count   -4.147e-05   6.78e-05     -0.612      0.541      -0.000    9.14e-05
# Critic_Review_Count  9.131e-05      0.000      0.590      0.555      -0.000       0.000
# Runtime                 0.0015      0.001      2.432      0.015       0.000       0.003
# Foreign                -0.0772      0.028     -2.726      0.006      -0.133      -0.022
# UC_Ratio               -0.0483      0.013     -3.808      0.000      -0.073      -0.023
# Description_Len        -0.0006      0.001     -0.882      0.378      -0.002       0.001
# Review_Len              0.0011   6.26e-05     16.988      0.000       0.001       0.001
# Fall                   -0.0265      0.028     -0.965      0.335      -0.080       0.027
# Spring                 -0.0627      0.026     -2.370      0.018      -0.115      -0.011
# Summer                 -0.0041      0.026     -0.157      0.875      -0.055       0.047
# Winter                 -0.0374      0.028     -1.314      0.189      -0.093       0.018
# ==============================================================================
# Omnibus:                      269.484   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              393.342
# Skew:                          -0.572   Prob(JB):                     3.86e-86
# Kurtosis:                       4.047   Cond. No.                     1.02e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.86e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X = post_ebert.drop(['Season', 'Title', 'Year', 'EbertStars'], axis=1)
y = post_ebert['EbertStars']

# %%
predictions = results.predict(sm.add_constant(X))
y_round = [half_round(y) for y in predictions]
print('Linear Regression Error: ', mean_squared_error(y, y_round))
# Out:
# Linear Regression Error:  0.614533965245

# %% [markdown]
# ## Visuals

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(results, ax=ax, criterion="cooks")

# %% [markdown]
# There are a few worrisome observations. 3686 has small residule and large leverage. Several other points seem to have high positive or negative residuals as less (greater than or less than -2/+2)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
fig = sm.graphics.plot_ccpr(results, "Metascore", ax=ax)

# %% [markdown]
# As you can see, the relationship between Ebert Stars explained by Metascore conditional on the other variables seems to be linear, though there are several other observations that are exerting considerable influence on the relationship.

# %%
fig, ax = plt.subplots(figsize=(12, 8))
fig = sm.graphics.plot_fit(results, "IMDB_Rating", ax=ax)

# %% [markdown]
# We can see the fitted values vs. a choosen independent variable, which in this case is IMDB Rating. You can see the prediction confidence intervals as well.

# %% [markdown]
# # Modeling (Lasso Regression with Genres, Directors, Actors, Decades)

# %% [markdown]
# Now let's create an initial model with all features, including those high-dimensional ones like directors and actors. We'll use Scikit-learn and Lasso to perform automatic feature subset selection.
#
# Also, let's focus on predicting Ebert's ratings only (e.g., those before 2013).

# %%
regression_df = ebert_imdb_df\
    .drop(['Title', 'Description', 'URL', 'Country', 'Review', 'Release_Date', 
           'Season', 'Rating'], axis=1)
    
regression_df = regression_df[regression_df['Year'] < 2013]
regression_df.shape
# Out:
# (6407, 4798)

# %%
print('IMDB_Rating', ebert_imdb_df['IMDB_Rating'].isnull().sum())
print('Rating_Count', ebert_imdb_df['Rating_Count'].isnull().sum())
print('Metascore', ebert_imdb_df['Metascore'].isnull().sum())
print('User_Review_Count', ebert_imdb_df['User_Review_Count'].isnull().sum())
print('Critic_Review_Count', ebert_imdb_df['Critic_Review_Count'].isnull().sum())
print('EbertStars', ebert_imdb_df['EbertStars'].isnull().sum())
print('Year', ebert_imdb_df['Year'].isnull().sum())
print('Runtime', ebert_imdb_df['Runtime'].isnull().sum())
print('UC_Ratio', ebert_imdb_df['UC_Ratio'].isnull().sum())
# Out:
# IMDB_Rating 35
# Rating_Count 35
# Metascore 2451
# User_Review_Count 111
# Critic_Review_Count 0
# EbertStars 0
# Year 0
# Runtime 413
# UC_Ratio 111

# %% [markdown]
# We can see that Metascore is the feature with the highest number of `NaN` values. Although it would be nice to keep all that data it is likely that Metascore will be selected by Lasso for being a good predictor.

# %%
regression_df = regression_df.dropna()
regression_df.shape
# Out:
# (3928, 4798)

# %% [markdown]
# Unfortunately, after removing `NaN` values we go from over 6400 movies to under 4000 movies.

# %% [markdown]
# Let's also play around with a couple of promising features (e.g., IMDB Rating and Metascore). Let's create some artificial features based on these 2 and see whether Lasso picks them as good predictors.

# %%
regression_df['IMDB_Squared'] = regression_df['IMDB_Rating'] ** 2
regression_df['Metascore_Squared'] = regression_df['Metascore'] ** 2
regression_df['IMDB*Metascore'] = regression_df['IMDB_Rating'] * regression_df['Metascore']

# %%
regression_df.head()
# Out:
#      IMDB_Rating  Rating_Count  Metascore  User_Review_Count  \
# 87           7.3       23271.0       59.0              109.0
# 123          6.1        2576.0       77.0               18.0
# 139          6.3       18697.0       48.0               61.0
# 202          7.1        3383.0       72.0               21.0
# 214          6.6       77922.0       48.0              246.0
#
#      Critic_Review_Count  EbertStars    Year  Runtime  Foreign  UC_Ratio  \
# 87                 180.0         3.0  1989.0     99.0        0  0.605556
# 123                 89.0         2.5  2001.0    103.0        0  0.202247
# 139                112.0         3.0  2005.0     87.0        0  0.544643
# 202                101.0         3.0  1983.0    110.0        0  0.207921
# 214                320.0         3.0  2010.0    105.0        0  0.768750
#
#           ...        1950  1960  1970  1980  1990  2000  2010  IMDB_Squared  \
# 87        ...           0     0     0     1     0     0     0         53.29
# 123       ...           0     0     0     0     0     1     0         37.21
# 139       ...           0     0     0     0     0     1     0         39.69
# 202       ...           0     0     0     1     0     0     0         50.41
# 214       ...           0     0     0     0     0     0     1         43.56
#
#      Metascore_Squared  IMDB*Metascore
# 87              3481.0           430.7
# 123             5929.0           469.7
# 139             2304.0           302.4
# 202             5184.0           511.2
# 214             2304.0           316.8
#
# [5 rows x 4801 columns]

# %%
train, test = train_test_split(regression_df, test_size=0.15, random_state=2)
X_train = train.drop(['EbertStars'], axis=1)
y_train = train['EbertStars']
X_test = test.drop(['EbertStars'], axis=1)
y_test = test['EbertStars']

# %% [markdown]
# ## Lasso
#
# [Lasso Regularization](http://scikit-learn.org/stable/modules/linear_model.html#lasso) (which uses `L1` penalty) is very useful when we have high-dimensional data and a sparse solution like we believe to be the case here. Instead of just reducing the coefficients like Ridge Regression (which uses `L2` penalty) does it actually brings them to zero if the feature is not a good predictor — effectively accomplishing feature subset selection.
#
# Scikit-learn's [`Lasso`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) class takes as hyperparameter `alpha` which is a constant that multiplies the `L1` term. If `alpha=0` then it uses all the original features. As `alpha` increases, Lasso selects fewer and fewer features.
#
# Following is an algorithm to select `alpha` so that it maximizes `R`<sup>2</sup>. Let's also make sure we normalize the data so that we don't have high values like `Runtime` alongside low ones like the dummy variables.

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error
import decimal
import math

def lasso_r2_score(alpha):
    lasso = linear_model.Lasso(alpha=alpha, normalize=True)
    lasso.fit(X_train, y_train)
    y_pred = lasso.predict(X_test)
    return lasso, r2_score(y_test, y_pred)

def n_selected_features(lasso):
    selected_features_idx = np.where(lasso.coef_ != 0)[0]
    return len(selected_features_idx)

def remove_float_inconsistency(float_):
    float_str = str(float_)
    return float(float_str)

def log(alpha, verbose):
    if verbose:
        print('calculating r2 with alpha={}'.format(alpha))

def lasso_best_alpha(alpha_min=0, alpha_max=0.01, verbose=False):
    """
    This function tries to find the best value for Lasso's hyperparameter 'alpha'.
    
    It iterates over ranges of ever smaller decimal values and only stops when the best and
    second best alpha values found yield a Lasso model with the same number of features.
    """
    best_lasso = None
    step = decimals = 10 ** (decimal.Decimal(str(alpha_max)).as_tuple().exponent - 1)
    while True:
        best_r2 = -math.inf
        second_best_r2 = -math.inf
        best_alpha = -1
        second_best_alpha = -1
        for alpha in np.arange(alpha_min, alpha_max+step, step):
            if alpha == 0:
                continue
            
            alpha = remove_float_inconsistency(alpha)
            alpha_max = remove_float_inconsistency(alpha_max)
            alpha_min = remove_float_inconsistency(alpha_min)
            log(alpha, verbose)
            lasso, r2 = lasso_r2_score(alpha)
            
            if r2 > best_r2:
                second_best_r2 = best_r2
                best_r2 = r2
                second_best_alpha = best_alpha
                best_alpha = alpha
                second_best_lasso = best_lasso
                best_lasso = lasso
            else:
                previous_second_best = second_best_r2
                if r2 > second_best_r2:
                    second_best_r2 = r2
                    second_best_alpha = alpha
                    second_best_lasso = lasso
                break
        
        if best_alpha == alpha_max:
            lower_level_alpha = best_alpha + step
            log(lower_level_alpha, verbose)
            lower_level_lasso, lower_level_r2 = lasso_r2_score(lower_level_alpha)
            
            if lower_level_r2 > second_best_r2:
                second_best_alpha = lower_level_alpha
                second_best_lasso = lower_level_lasso
                second_best_r2 = lower_level_r2
                alpha_max = best_alpha + step
                alpha_min = best_alpha
                
        elif best_alpha == alpha_min or (alpha_min == 0 and best_alpha == step):
            if alpha_min == 0:
                lower_level_alpha = best_alpha - step/10
            else:
                lower_level_alpha = best_alpha - step

            log(lower_level_alpha, verbose)
            lower_level_lasso, lower_level_r2 = lasso_r2_score(lower_level_alpha)
            
            if lower_level_r2 > second_best_r2:
                second_best_alpha = lower_level_alpha
                second_best_lasso = lower_level_lasso
                second_best_r2 = lower_level_r2
                alpha_max = best_alpha
                alpha_min = best_alpha - step
        else:
            alpha_max = max(best_alpha, second_best_alpha)
            alpha_min = min(best_alpha, second_best_alpha)
            
        step = step / 10
        
        if n_selected_features(best_lasso) == n_selected_features(second_best_lasso):
            return best_lasso, best_r2

# %%
lasso, r2 = lasso_best_alpha(verbose=True)
# Out:
# calculating r2 with alpha=0.001
# calculating r2 with alpha=0.002
# calculating r2 with alpha=0.0009
# calculating r2 with alpha=0.0001
# calculating r2 with alpha=0.0002
# calculating r2 with alpha=0.0003
# calculating r2 with alpha=0.0004
# calculating r2 with alpha=0.0002
# calculating r2 with alpha=0.00021
# calculating r2 with alpha=0.00022
# calculating r2 with alpha=0.00023
# calculating r2 with alpha=0.00024
# calculating r2 with alpha=0.00025
# calculating r2 with alpha=0.00026
# calculating r2 with alpha=0.00027
# calculating r2 with alpha=0.00025
# calculating r2 with alpha=0.000251
# calculating r2 with alpha=0.000252
# calculating r2 with alpha=0.000253
# calculating r2 with alpha=0.000254
# calculating r2 with alpha=0.000255
# calculating r2 with alpha=0.000256
# calculating r2 with alpha=0.000257
# calculating r2 with alpha=0.000258
# calculating r2 with alpha=0.000259
# calculating r2 with alpha=0.00026
# calculating r2 with alpha=0.000261
# calculating r2 with alpha=0.00026
# calculating r2 with alpha=0.0002601
# calculating r2 with alpha=0.0002602
# calculating r2 with alpha=0.0002603
# calculating r2 with alpha=0.0002604
# calculating r2 with alpha=0.0002605
# calculating r2 with alpha=0.0002606
# calculating r2 with alpha=0.0002607
# calculating r2 with alpha=0.0002608
# calculating r2 with alpha=0.0002609
# calculating r2 with alpha=0.000261
# calculating r2 with alpha=0.0002611

# %%
print('alpha =', lasso.alpha)
print('r2 =', r2)
# Out:
# alpha = 0.0002611
# r2 = 0.4873062371

# %% [markdown]
# We can see that after trying multiple values for `alpha` the algorithm chose 0.0002611 which yields a Lasso Regression model with an `R`<sup>2</sup> of 0.4873062371.
#
# Now let's see how many and which features were selected by Lasso.

# %%
selected_features_idx = np.where(lasso.coef_ != 0)[0]
print(len(selected_features_idx))

selected_features = X_train.iloc[:, selected_features_idx]
selected_features.columns.values
# Out:
# 393
# array(['IMDB_Rating', 'Metascore', 'Runtime', 'Foreign', 'UC_Ratio',
#        'Review_Len', 'Spring', 'PG', 'PG-13', 'Animation', 'Comedy',
#        'Crime', 'Drama', 'Horror', 'Sci-Fi', 'Western', 'Adam Wingard',
#        'Agnieszka Wojtowicz-Vosloo', 'Agnès Varda', 'Alexandre Aja',
#        'Alice Winocour', 'Andrew Bergman', 'Andrzej Bartkowiak',
#        'Anne Fontaine', 'Anthony Fabian', 'Ariel Vromen', 'Asif Kapadia',
#        'Billy Ray', 'Boaz Yakin', 'Bob Balaban', 'Brian Koppelman',
#        'Bronwen Hughes', 'Bruce McCulloch', 'Bruno Barreto',
#        'Bryan Bertino', 'Bryan Singer', 'Buddy Van Horn', 'Callie Khouri',
#        'Carl Reiner', 'Chris Carter', 'Christopher Cain', 'Chuck Russell',
#        'Daniel Nettheim', 'Darrell Roodt', 'David Cronenberg',
#        'David Lynch', 'David Mirkin', 'David S. Goyer', 'Des McAnuff',
#        'Don Bluth', 'Doug Liman', 'Dover Koshashvili', 'Emile Ardolino',
#        'Ericson Core', 'François Girard', 'Gareth Edwards', 'Gareth Evans',
#        "Gavin O'Connor", 'Gregory Hoblit', 'Guy Ritchie', 'Hal Hartley',
#        'Harry Elfont', 'Henry Joost', 'Henry Winkler', 'Ilya Naishuller',
#        'J.B. Rogers', 'James Foley', 'Jared Hess', 'Jason Moore',
#        'Jean-Luc Godard', 'Jeff Garlin', 'Jim Jarmusch', 'Joe Roth',
#        'Joe Swanberg', 'Joel Coen', 'Joel Schumacher', 'John D. Hancock',
#        'John Schlesinger', 'John Woo', 'Jonathan Sobol', 'Julia Loktev',
#        'Julie Taymor', 'Ken Loach', 'Kirk De Micco', 'Larry Clark',
#        'Leslie Stevens', 'Louis Leterrier', 'Luc Besson',
#        'Lucile Hadzihalilovic', 'Mark Rosman', 'Martin Brest',
#        'Martin McDonagh', 'Matt Bettinelli-Olpin', 'Mel Gibson',
#        'Michael Bay', 'Michael Cristofer', 'Michael Haneke',
#        'Michael Mann', 'Michael Polish', 'Mikael Salomon', 'Mike Barker',
#        'Mike Mitchell', 'Neil Burger', 'Ole Bornedal', 'Pascale Ferran',
#        'Patricia Rozema', 'Paul W.S. Anderson', 'Peter A. Dowling',
#        'Peter Hewitt', 'Peter Howitt', 'Peter Jackson', 'Peter Segal',
#        'Phil Alden Robinson', 'Richard Eyre', 'Richard Kelly',
#        'Richard Marquand', 'Rob Bowman', 'Robert Greenwald', 'Rod Lurie',
#        'Rose Troche', 'Ross Katz', 'Rufus Norris', 'Sally Potter',
#        'Sam Raimi', 'Sam Weisman', 'Scott Mann', 'Scott McGehee',
#        'Sean Penn', 'Shawn Levy', 'Sofia Coppola', 'Stefan Ruzowitzky',
#        'Steve Miner', 'Steven R. Monroe', 'Steven Spielberg',
#        'Tamra Davis', 'Terry Gilliam', 'Terry Jastrow',
#        'Thomas Vinterberg', 'Todd Phillips', 'Tom Six', 'Trey Parker',
#        'Tyler Perry', 'Vincent Ward', 'Wallace Wolodarsky', 'Walter Hill',
#        'Warren Beatty', 'Wes Anderson', 'Wim Wenders', 'Yimou Zhang',
#        'Zack Snyder', '50 Cent', 'AJ Bowen', 'Aaron Stanford',
#        'Aaron Taylor-Johnson', 'Alan Rickman', 'Alice Englert',
#        'Alice Krige', 'Alicia Silverstone', 'Amy Adams', 'Ananda George',
#        'Andrew Bryniarski', 'Andrew Dice Clay', 'Andrew Howard',
#        'Andrew Scott', 'Andy Samberg', 'Angela Lansbury', 'Anna Faris',
#        'Anna Paquin', 'Anson Mount', 'Ashlynn Yennie', 'Ashton Kutcher',
#        'Baoqiang Wang', 'Bess Armstrong', 'Bidzina Gujabidze',
#        'Billy Connolly', 'Bob Dylan', 'Bobby Cannavale', 'Brian Posehn',
#        'Bryan Cranston', 'Chace Crawford', 'Chandler Canterbury',
#        'Charlie Booty', 'Chiwetel Ejiofor', 'Christian Stevens',
#        'Christine Taylor', 'Christopher McDonald', 'Christopher Plummer',
#        'Corey Allen', 'Corey Burton', 'Daniel Stern', 'Danny Glover',
#        'Dave Bautista', 'Dave Chappelle', 'David Duchovny',
#        'David Koechner', 'Debra Winger', 'Dennis Haysbert', 'Dieter Laser',
#        'Dolly Parton', 'Dylan McDermott', 'Dylan Walsh', 'Edouard Baer',
#        'Ellen Barkin', 'Eric Cantona', 'Eva Birthistle',
#        'Eva van der Gucht', 'Faye Dunaway', 'G.W. Bailey', 'Gabriel Byrne',
#        'Garry Shandling', 'Gene Hackman', 'Geneviève Bujold',
#        'George Dzundza', 'Gio Perez', 'Giovanna Mezzogiorno',
#        'Giovanni Ribisi', 'Gwyneth Paltrow', 'Hani Furstenberg',
#        'Hank Azaria', 'Harrison Ford', 'Hugh Laurie', 'Iain Glen',
#        'Ian McElhinney', 'Idris Elba', 'Iko Uwais', 'Ioan Gruffudd',
#        'Isabelle Adjani', 'Isabelle Fuhrman', 'J.D. Evermore', 'Jake Abel',
#        'Jake Busey', 'Jake Gyllenhaal', 'James Fleet', 'James Garner',
#        'Jamie Foxx', 'Jane Fonda', 'January Jones', 'Jason Isaacs',
#        'Jason Lee', 'Jason Spevack', 'Jason Statham', 'Jeff Branson',
#        'Jeffrey Dean Morgan', 'Jenna Fischer', 'Jennifer Ehle',
#        'Jennifer Garner', 'Jennifer Grey', 'Jeremy Sumpter',
#        'Jeroen Krabbé', "Jerry O'Connell", 'Jerry Orbach',
#        'Jerry Seinfeld', 'Jesse Bradford', 'Jillian Murray', 'Jim Parsons',
#        'Jimmy Fallon', 'Joe Anderson', 'John Candy', 'John Heard',
#        'Johnathon Schaech', 'Johnny Depp', 'Jonathan Jackson',
#        'Jonathan Tucker', 'Jordana Brewster', 'Joshua Jackson',
#        'José Dumont', 'Judge Reinhold', 'Julie Andrews', 'Kane Hodder',
#        'Kate Capshaw', 'Kate Hudson', 'Kate Manx', 'Kate Mara',
#        'Katherine LaNasa', 'Katheryn Winnick', 'Kerry Fox',
#        'Kerry Washington', 'Kevin James', 'Kim Cattrall', 'Kim Greist',
#        'Kristen Johnston', 'Krister Henriksson', 'Kyle MacLachlan',
#        'Kyra Sedgwick', 'Laurie Holden', 'Lee Evans', 'Leslie Bibb',
#        'Levi Miller', 'Liam Neeson', 'Lily James', 'Logan Marshall-Green',
#        'Lorraine Bracco', 'Lucy Liu', 'Luke Bracey', 'Marton Csokas',
#        'Mary Elizabeth Ellis', 'Max Irons', 'Maya Stange', 'Meat Loaf',
#        'Melissa McCarthy', 'Mercedes Ruehl', 'Michael Angarano',
#        'Michael Badalucco', 'Michael Ealy', 'Michael Jackson',
#        'Michael Jai White', 'Michael McKean', 'Michael Shannon',
#        'Michaela Watkins', 'Michelle Krusiec', 'Michelle Pfeiffer',
#        'Michelle Rodriguez', 'Miles Teller', 'Mira Sorvino',
#        'Molly Ephraim', 'Morgana Davies', 'Mía Maestro', 'Nathan Phillips',
#        'Nick Kroll', 'Nicola Peltz', 'Noah Fleiss', 'Olivia Wilde',
#        'Owen Wilson', 'Pam Grier', 'Paolo Bonacelli', 'Pascale Bussières',
#        'Pat Morita', 'Patrick Wilson', 'Paula Patton', 'Paulina García',
#        'Pedro Armendáriz Jr.', 'Peter Coyote', 'Peter Krause',
#        'Peter Sarsgaard', 'Powers Boothe', 'Rachel Nichols', 'Randy Quaid',
#        'Ray Liotta', 'Ray Sahetapy', 'Ray Wise', 'Rebecca De Mornay',
#        'Rebel Wilson', 'Reggie Bannister', 'Remo Girone',
#        'Richard Jenkins', 'Robbie Amell', 'Robert Loggia',
#        'Robert Sean Leonard', 'Robin Williams', 'Rory Culkin',
#        'Rory J. Saper', 'Ross Partridge', 'Rupert Friend',
#        'Russell M. Haeuser', 'Sarah Butler', 'Sarah Jessica Parker',
#        'Sarah Michelle Gellar', 'Sean Hayes', 'Sean Young', 'Shad Moss',
#        'Sharni Vinson', 'Shirley MacLaine', 'Sigourney Weaver',
#        'Simon Pegg', 'Skeet Ulrich', 'Sonya Davison', 'Stephen Baldwin',
#        'Steve Martin', 'Steven Seagal', 'Sylvia Hoeks', 'Tara Reid',
#        'Taraji P. Henson', 'Taryn Manning', 'Taylor Lautner',
#        'Terrence Mann', 'Thandie Newton', 'Tim Roth', 'Tobias Menzies',
#        'Tony Hale', 'Tony Leung Chiu-Wai', 'Tracey Ullman', 'Trent Ford',
#        'Tyne Daly', "Vincent D'Onofrio", 'Ving Rhames', 'Wallace Shawn',
#        'Warren Oates', 'William Fichtner', 'Zac Efron', 'Zachary Knighton',
#        'Zoe Saldana', 1960, 2010], dtype=object)

# %% [markdown]
# At 393 this is about only 8% of the 4801 features we originally fed the algorithm with.
#
# Besides many actors and directors, Lasso kept as good predictors the following features:
# - `IMDB_Rating`
# - `Metascore`
# - `Runtime`
# - `Foreign`
# - `UC_Ratio`
# - `Review_Len`
# - `Spring`
# - `PG`
# - `PG-13`
# - `1960`
# - `2010`
# - `Animation`
# - `Comedy`
# - `Crime`
# - `Drama`
# - `Horror`
# - `Sci-Fi`
# - `Western`

# %% [markdown]
# Before we move on and calculate the Mean Squared Error, let's have a glympse at the final array of coefficients generated by Lasso (which contains 0's for features not selected).

# %%
lasso.coef_[:20]
# Out:
# array([ 0.07181479, -0.        ,  0.02464188, -0.        ,  0.        ,
#         0.        ,  0.00018894, -0.0281419 , -0.02899991, -0.        ,
#         0.00088172,  0.        , -0.00251573,  0.        , -0.        ,
#         0.        , -0.        ,  0.01647289, -0.02647441,  0.        ])

# %% [markdown]
# Moreover, once we had the best value for `alpha` this is how many iterations of the Lasso algorithm were necessary to reach the final model:

# %%
lasso.n_iter_
# Out:
# 21

# %%
y_pred_train = lasso.predict(X_train)
print('train dataset r2 score:', r2_score(y_train, y_pred_train))
print('train dataset mean squared error:', mean_squared_error(y_train, y_pred_train))
# Out:
# train dataset r2 score: 0.589756461562
# train dataset mean squared error: 0.277054393598

# %%
y_pred_train_rounded = [half_round(y) for y in y_pred_train]
print('[rounded] train dataset r2 score:', r2_score(y_train, y_pred_train_rounded))
print('[rounded] train dataset mean squared error:', 
      mean_squared_error(y_train, y_pred_train_rounded))
# Out:
# [rounded] train dataset r2 score: 0.546974712243
# [rounded] train dataset mean squared error: 0.305946674655

# %%
y_pred = lasso.predict(X_test)
print('test dataset r2 score:', r2_score(y_test, y_pred))
print('test dataset mean squared error:', mean_squared_error(y_test, y_pred))
# Out:
# test dataset r2 score: 0.4873062371
# test dataset mean squared error: 0.370417929817

# %%
y_pred_rounded = [half_round(y) for y in y_pred]
print('[rounded] test dataset r2 score:', r2_score(y_test, y_pred_rounded))
print('[rounded] dataset mean squared error:', mean_squared_error(y_test, y_pred_rounded))
# Out:
# [rounded] test dataset r2 score: 0.467475149105
# [rounded] dataset mean squared error: 0.384745762712

# %% [markdown]
# We could further improve this model by using cross-validation to choose a good `alpha` (i.e., with the [LassoCV](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html) class). However, since the train dataset `R`<sup>2</sup> is not even close to a good value like `0.9` the main problem with this model is that it is underfitting as opposed to overfitting. Let's plot the [learning curves](http://scikit-learn.org/stable/modules/learning_curve.html#learning-curve) to see if we can confirm that.

# %%
# adapted from http://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html
def plot_learning_curves(train_sizes, train_scores, test_scores):
    plt.figure(figsize=(11, 9))
    plt.title("Learning Curves")
    plt.xlabel("Number of examples")
    plt.ylabel("$R^2$")
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, 
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training $R^2$")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Test $R^2$")

    plt.legend(loc="best")
    plt.show()

# %%
from sklearn.model_selection import learning_curve

X = regression_df.drop(['EbertStars'], axis=1)
y = regression_df['EbertStars']
train_sizes, train_scores, test_scores = learning_curve(lasso, X, y, n_jobs=-1)

# %%
plot_learning_curves(train_sizes, train_scores, test_scores)

# %% [markdown]
# We can see from the plot that we are indeed underfitting as both curves should converge further (similar to these [learning curves](http://scikit-learn.org/stable/_images/sphx_glr_plot_learning_curve_001.png)). If on one side, dropping that many examples that didn't have a Metascore hurt the model, on the other hand dropping the Metascore feature would also hurt. Anyhow, giving that our training `R`<sup>2</sup> is low, even if we had more data we would have a model that couldn't predict so well.

# %% [markdown]
# # Conclusions, Lessons Learned and Further Research

# %% [markdown]
# The latter model with the addition of high-dimensional features like Actors, Directors and Genres, as well as feature subset selection performed by Lasso yielded a better model with higher `R`<sup>2</sup> and lower Mean Squared Error than what we could accomplish before.
#
# However, it is not that much better on the test set and, even worse, it is not good enough on the train set. That indicates we're either missing some highly predictive features (i.e., budget, box office, screenwriter, studio, awards won by movies/actors/directors, whether a movie is part of a series) or that maybe this problem is not linear and that we should try alternative Machine Learning algorithms in the future (i.e., Tree-based methods, SVM, Neural Networks).
#
# It could also be the case that Ebert's ratings were grounded in much more subjective matters that not even adding the proposed new features or trying alternative Machine Learning methods were going to yield predictions with much lower error.
#
# Nonetheless, another are of further research could be to model this problem as a Classification problem (as opposed to a Regression one). After all, Eberts' ratings were discrete, with 9 possible values ranging from 0 to 4.
